# %%
import pandas as pd
# pd.set_option('display.max_rows', 100)

import numpy as np

# %%
df = pd.read_csv("train-1.csv")
df2 = pd.read_csv("train-2.csv")
# df.head(100)
# df.head(None)
finaldf = pd.concat([df, df2], axis=0, join='inner').sort_index()
finaldf.head(100)
# Out:
#     Unnamed: 0     tconst                         primaryTitle  \
# 0            4  tt0010600                             The Doll
# 0            6  tt0011607                   The Parson's Widow
# 1           17  tt0014358                          The Pilgrim
# 1            7  tt0011841                        Way Down East
# 2            9  tt0012494                              Déstiny
# 2           20  tt0014611                           Why Worry?
# 3           25  tt0015163                        The Navigator
# 3           44  tt0016847                                Faust
# 4           63  tt0018773                           Thé Circús
# 4           38  tt0016220             The Phantom of the Opera
# 5           68  tt0019109                             Lonesome
# 5           42  tt0016630                      Báttling Bútlér
# 6           77  tt0020122                           Lucky Star
# 6           81  tt0021015                 Juno and the Paycock
# ...
